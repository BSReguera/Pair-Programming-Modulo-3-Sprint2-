# %% [markdown]
# # PAIR PROGRAMMING - MODULO 3 - LECCION 11- ETL I

# %% [markdown]
# Introducción - Ejercicios ETL Parte I:
#
# En este caso trabajas en una empresa de venta al por menor de productos italianos y debes realizar la limpieza, transformación e integración de datos de ventas, productos y clientes para su análisis. Los pasos que deberás seguir en este ejercicio son:

# %%
# Importaciones de librerias necesarias:
import pandas as pd

# Configuración
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
pd.set_option('display.float_format', '{:.2f}'.format) # para formaterar los numeros a 2 decimales

# %% [markdown]
# 1. Lectura de la Información:
#
# - Leer los archivos CSV (ventas.csv, productos.csv, clientes.csv).
#
# - Explorar los conjuntos de datos para comprender su estructura, columnas, tipos de datos, etc.

# %%
# Apertura y lectura del archivo csv
ventas_df = pd.read_csv('ventas.csv')
ventas_df
# Out:
#     ID_Cliente ID_Producto Fecha_Venta  Cantidad  Total
# 0          723          A1  2023-11-22         2  17.98
# 1          498          C3  2023-11-21         1   5.49
# 2          121          D4  2023-11-20         3  32.97
# 3          885         L12  2023-11-19         1   6.49
# 4          347         Q17  2023-11-18         2   7.98
# ..         ...         ...         ...       ...    ...
# 95         234       AR136  2023-09-04         1   8.45
# 96         987       AS137  2023-09-03         2  12.50
# 97         543       AT138  2023-09-02         1   4.75
# 98         234       AU139  2023-09-01         2   9.98
# 99         987       AV140  2023-08-31         1   5.25
#
# [100 rows x 5 columns]

# %%
productos_df = pd.read_csv('productos.csv', error_bad_lines=False, warn_bad_lines=False)
productos_df
# Out:
#                                   ID       Nombre_Producto  Categoría  Precio  \
# A1                  Pizza Margherita     Platos Preparados       8.99  Italia
# B2            Risotto de Champiñones     Platos Preparados       6.75  Italia
# C3                          Tiramisú               Postres       5.49  Italia
# D4                         Panettone            Repostería      10.99  Italia
# E5                       Orecchiette       Productos Secos       4.29  Italia
# F6               Polenta Tradicional               Harinas       3.75  Italia
# G7              Mozzarella di Bufala     Productos Lácteos       9.25  Italia
# J10                    Arroz Arborio       Productos Secos       4.89  Italia
# K11                    Café Espresso                  Café       6.49  Italia
# L12      Sardinas en Aceite de Oliva  Pescados en Conserva       3.99  Italia
# N14                Gnocchi de Patata  Productos Congelados       5.25  Italia
# O15   Ravioli de Ricotta y Espinacas  Productos Congelados       6.75  Italia
# Q17                   Pasta de Trigo       Productos Secos       3.99  Italia
# R18           Salsa de Tomate Casera                Salsas       2.49  Italia
# S19     Aceite de Oliva Virgen Extra               Aceites       9.99  Italia
# T20                  Queso Parmesano     Productos Lácteos       7.89  Italia
# U21                   Salami Toscano             Embutidos       5.75  Italia
# W23                  Gelato de Limón               Helados       4.25  Italia
# X24                          Cannoli                Dulces       3.99  Italia
# Y25                       Cacciatore             Embutidos       6.75  Italia
# GG33                   Ciceri e Tria     Platos Preparados       5.89  Italia
#
#                                                  Origen  \
# A1                    Clásica pizza italiana con tomate
# B2              Risotto cremoso con champiñones frescos
# C3    Postre clásico italiano con capas de bizcocho ...
# D4    Pan dulce navideño italiano con frutas confita...
# E5    Pequeñas pastas con forma de orecchiette ideal...
# F6    Harina de maíz italiana para preparar la tradi...
# G7      Mozzarella fresca elaborada con leche de búfala
# J10   Arroz de grano corto perfecto para risottos it...
# K11   Café espresso italiano con un aroma y sabor in...
# L12                 Sardinas frescas en aceite de oliva
# N14                          Gnocchi de patata italiana
# O15    Raviolis rellenos de ricotta y espinacas frescas
# Q17             Deliciosa pasta de trigo durum italiana
# R18             Elaborada con tomates italianos maduros
# S19   Aceite de oliva prensado en frío de las mejore...
# T20                            El famoso queso italiano
# U21   Salami de cerdo italiano curado con hierbas y ...
# W23    Gelato italiano cremoso con sabor a limón fresco
# X24   Postre siciliano con masa crujiente rellena de...
# Y25   Salchichas de cerdo condimentadas con hierbas ...
# GG33  Plato de pasta tradicional de Apulia con garba...
#
#                                             Descripción
# A1                        mozzarella fresca y albahaca.
# B2         una delicia italiana para disfrutar en casa.
# C3                         mascarpone y cacao en polvo.
# D4                     un regalo tradicional en Italia.
# E5                                                  NaN
# F6                        perfecta como acompañamiento.
# G7                      suave y deliciosamente cremosa.
# J10             absorbe los sabores de forma exquisita.
# K11        la esencia de la cultura del café en Italia.
# L12                    un bocado delicioso y saludable.
# N14                ideales con salsa de tomate o crema.
# O15                             simplemente deliciosos.
# Q17           ideal para platos de pasta tradicionales.
# R18    una receta tradicional que realza el sabor de...
# S19                   perfecto para aderezos y cocinar.
# T20    madurado durante meses para obtener su sabor ...
# U21    un acompañamiento perfecto para tablas de emb...
# W23                  un postre refrescante y delicioso.
# X24                            una delicia tradicional.
# Y25                          perfectas para aperitivos.
# GG33                             una combinación única.

# %%
clientes_df = pd.read_csv('clientes.csv')
clientes_df
# Out:
#        id  first_name last_name                         email  gender  \
# 0       1       Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 1       2        Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 2       3  Michaeline   Paynton            mpaynton2@narod.ru  Female
# 3       4      Filmer    Eirwin            feirwin3@intel.com     NaN
# 4       5      Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
# ..    ...         ...       ...                           ...     ...
# 995   996         Ray    Tarpey      rtarpeyrn@bravesites.com  Female
# 996   997        Flem  Roderham       froderhamro@dropbox.com    Male
# 997   998   Winifield    Blakes         wblakesrp@jiathis.com    Male
# 998   999      Lanita  Espinosa        lespinosarq@discuz.net  Female
# 999  1000     Grissel   Siberry     gsiberryrr@wikispaces.com  Female
#
#                             City Country                   Address
# 0              Palma De Mallorca   Spain  076 Rockefeller Crossing
# 1                           Lugo   Spain        0046 Utah Junction
# 2                            NaN   Spain          0 Corry Crossing
# 3                           Leon   Spain       5 American Ash Road
# 4    Hospitalet De Llobregat, L'   Spain         9289 Merry Circle
# ..                           ...     ...                       ...
# 995                       Zamora   Spain     36384 Sommers Terrace
# 996                   Pontevedra   Spain    93177 Eastwood Parkway
# 997                         Vigo   Spain       03044 Grayhawk Road
# 998                 Dos Hermanas   Spain        2 Schmedeman Drive
# 999                         Leon   Spain     42274 Waywood Terrace
#
# [1000 rows x 8 columns]

# %%
lista_df = [ventas_df, productos_df, clientes_df]

# %%
def exploracion (lista):
    """Esta función proporciona una descripción personalizada de un DataFrame,
    incluyendo estadísticas descriptivas y tipos de datos de cada columna.
    
    Argumentos:
    df : DataFrame de Pandas
        El DataFrame para el cual se generará la descripción"""
       
    for x, df in enumerate(lista):
        print(f"------Dataframe{x}------")
        print("-------Descripción numéricas:---------")
        print(df.describe())
        print("-------Descripción categoricas:---------")
        print(df.describe(include="O"))
        print("------Tipos:---------")
        print(df.dtypes)
        print("------Forma del DataFrame:------")
        print(df.shape)
        print("------Información:---------")
        print(df.info())
        print("------Nulos:---------")
        print(df.isnull().sum())
        print("------Duplicados:---------")
        print(df.duplicated().sum())
    
exploracion(lista_df)
# Out:
# ------Dataframe0------
# -------Descripción numéricas:---------
#        Id_cliente  Cantidad  Total
# count      100.00    100.00 100.00
# mean       572.05      1.65  11.20
# std        290.40      0.73   7.03
# min         29.00      1.00   4.25
# 25%        234.00      1.00   5.93
# 50%        543.00      1.50   8.75
# 75%        876.00      2.00  12.50
# max        987.00      3.00  32.97
# -------Descripción categoricas:---------
#        Id_producto Fecha_venta
# count          100         100
# unique         100          80
# top             A1  2023-10-24
# freq             1           2
# ------Tipos:---------
# Id_cliente       int64
# Id_producto     object
# Fecha_venta     object
# Cantidad         int64
# Total          float64
# dtype: object
# ------Forma del DataFrame:------
# (100, 5)
# ------Información:---------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id_cliente   100 non-null    int64
#  1   Id_producto  100 non-null    object
#  2   Fecha_venta  100 non-null    object
#  3   Cantidad     100 non-null    int64
#  4   Total        100 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ KB
# None
# ------Nulos:---------
# Id_cliente     0
# Id_producto    0
# Fecha_venta    0
# Cantidad       0
# Total          0
# dtype: int64
# ------Duplicados:---------
# 0
# ------Dataframe1------
# -------Descripción numéricas:---------
#        Categoría
# count      21.00
# mean        6.09
# std         2.27
# min         2.49
# 25%         4.25
# 50%         5.75
# 75%         6.75
# max        10.99
# -------Descripción categoricas:---------
#                       ID    Nombre_Producto  Precio  \
# count                 21                 21      21
# unique                21                 14       1
# top     Pizza Margherita  Platos Preparados  Italia
# freq                   1                  3      21
#
#                                    Origen                     Descripción
# count                                  21                              20
# unique                                 21                              20
# top     Clásica pizza italiana con tomate   mozzarella fresca y albahaca.
# freq                                    1                               1
# ------Tipos:---------
# ID                  object
# Nombre_Producto     object
# Categoría          float64
# Precio              object
# Origen              object
# Descripción         object
# dtype: object
# ------Forma del DataFrame:------
# (21, 6)
# ------Información:---------
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, A1 to GG33
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               21 non-null     object
#  1   Nombre_Producto  21 non-null     object
#  2   Categoría        21 non-null     float64
#  3   Precio           21 non-null     object
#  4   Origen           21 non-null     object
#  5   Descripción      20 non-null     object
# dtypes: float64(1), object(5)
# memory usage: 1.7+ KB
# None
# ------Nulos:---------
# ID                 0
# Nombre_Producto    0
# Categoría          0
# Precio             0
# Origen             0
# Descripción        1
# dtype: int64
# ------Duplicados:---------
# 0
# ------Dataframe2------
# -------Descripción numéricas:---------
#            Id
# count 1000.00
# mean   500.50
# std    288.82
# min      1.00
# 25%    250.75
# 50%    500.50
# 75%    750.25
# max   1000.00
# -------Descripción categoricas:---------
#        First_name  Last_name                     Email Gender    City Country  \
# count        1000       1000                       973    923     876     846
# unique        940        986                       973      8      55       1
# top       Germain  Bartolini  cdunsmore0@instagram.com   Male  Madrid   Spain
# freq            3          2                         1    424      51     846
#
#                Address
# count              959
# unique             958
# top     7 Toban Center
# freq                 2
# ------Tipos:---------
# Id             int64
# First_name    object
# Last_name     object
# Email         object
# Gender        object
# City          object
# Country       object
# Address       object
# dtype: object
# ------Forma del DataFrame:------
# (1000, 8)
# ------Información:---------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          1000 non-null   int64
#  1   First_name  1000 non-null   object
#  2   Last_name   1000 non-null   object
#  3   Email       973 non-null    object
#  4   Gender      923 non-null    object
#  5   City        876 non-null    object
#  6   Country     846 non-null    object
#  7   Address     959 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 62.6+ KB
# None
# ------Nulos:---------
# Id              0
# First_name      0
# Last_name       0
# Email          27
# Gender         77
# City          124
# Country       154
# Address        41
# dtype: int64
# ------Duplicados:---------
# 0

# %% [markdown]
# 2. Transformación de Datos:
#
# - Limpiar los datos: manejar valores nulos, eliminar duplicados si los hay, corregir errores tipográficos, etc.
#
# - Realizar la integración de datos: unir los conjuntos de datos apropiados para obtener una tabla única que contenga información de ventas junto con detalles de productos y clientes.
#
# - Aplicar transformaciones relevantes según sea necesario: por ejemplo, convertir tipos de datos, renombrar columnas, crear nuevas características derivadas, etc.

# %% [markdown]
# 2.1 Limpiar los datos: Manejar valores nulos, eliminar duplicados si los hay, corregir errores tipográficos, etc.

# %%
# El df productos_df cambia a cambio_productos con la eliminación de la primera columna, para su modificación.
cambio_productos = productos_df.reset_index()

# %%
cambio_productos.head()
# Out:
#   index                      ID    Nombre_Producto  Categoría  Precio  \
# 0    A1        Pizza Margherita  Platos Preparados       8.99  Italia
# 1    B2  Risotto de Champiñones  Platos Preparados       6.75  Italia
# 2    C3                Tiramisú            Postres       5.49  Italia
# 3    D4               Panettone         Repostería      10.99  Italia
# 4    E5             Orecchiette    Productos Secos       4.29  Italia
#
#                                               Origen  \
# 0                  Clásica pizza italiana con tomate
# 1            Risotto cremoso con champiñones frescos
# 2  Postre clásico italiano con capas de bizcocho ...
# 3  Pan dulce navideño italiano con frutas confita...
# 4  Pequeñas pastas con forma de orecchiette ideal...
#
#                                      Descripción
# 0                  mozzarella fresca y albahaca.
# 1   una delicia italiana para disfrutar en casa.
# 2                   mascarpone y cacao en polvo.
# 3               un regalo tradicional en Italia.
# 4                                            NaN

# %%
# Definir las nuevas cabeceras	
nuevas_cabeceras = ['ID', 'Nombre_Producto', 'Categoría', "Precio", "Origen", "Descripción", "Extra"]

# Asignar las nuevas cabeceras al DataFrame
cambio_productos.columns = nuevas_cabeceras
cambio_productos
# Out:
#       ID                 Nombre_Producto             Categoría  Precio  \
# 0     A1                Pizza Margherita     Platos Preparados    8.99
# 1     B2          Risotto de Champiñones     Platos Preparados    6.75
# 2     C3                        Tiramisú               Postres    5.49
# 3     D4                       Panettone            Repostería   10.99
# 4     E5                     Orecchiette       Productos Secos    4.29
# 5     F6             Polenta Tradicional               Harinas    3.75
# 6     G7            Mozzarella di Bufala     Productos Lácteos    9.25
# 7    J10                   Arroz Arborio       Productos Secos    4.89
# 8    K11                   Café Espresso                  Café    6.49
# 9    L12     Sardinas en Aceite de Oliva  Pescados en Conserva    3.99
# 10   N14               Gnocchi de Patata  Productos Congelados    5.25
# 11   O15  Ravioli de Ricotta y Espinacas  Productos Congelados    6.75
# 12   Q17                  Pasta de Trigo       Productos Secos    3.99
# 13   R18          Salsa de Tomate Casera                Salsas    2.49
# 14   S19    Aceite de Oliva Virgen Extra               Aceites    9.99
# 15   T20                 Queso Parmesano     Productos Lácteos    7.89
# 16   U21                  Salami Toscano             Embutidos    5.75
# 17   W23                 Gelato de Limón               Helados    4.25
# 18   X24                         Cannoli                Dulces    3.99
# 19   Y25                      Cacciatore             Embutidos    6.75
# 20  GG33                   Ciceri e Tria     Platos Preparados    5.89
#
#     Origen                                        Descripción  \
# 0   Italia                  Clásica pizza italiana con tomate
# 1   Italia            Risotto cremoso con champiñones frescos
# 2   Italia  Postre clásico italiano con capas de bizcocho ...
# 3   Italia  Pan dulce navideño italiano con frutas confita...
# 4   Italia  Pequeñas pastas con forma de orecchiette ideal...
# 5   Italia  Harina de maíz italiana para preparar la tradi...
# 6   Italia    Mozzarella fresca elaborada con leche de búfala
# 7   Italia  Arroz de grano corto perfecto para risottos it...
# 8   Italia  Café espresso italiano con un aroma y sabor in...
# 9   Italia                Sardinas frescas en aceite de oliva
# 10  Italia                         Gnocchi de patata italiana
# 11  Italia   Raviolis rellenos de ricotta y espinacas frescas
# 12  Italia            Deliciosa pasta de trigo durum italiana
# 13  Italia            Elaborada con tomates italianos maduros
# 14  Italia  Aceite de oliva prensado en frío de las mejore...
# 15  Italia                           El famoso queso italiano
# 16  Italia  Salami de cerdo italiano curado con hierbas y ...
# 17  Italia   Gelato italiano cremoso con sabor a limón fresco
# 18  Italia  Postre siciliano con masa crujiente rellena de...
# 19  Italia  Salchichas de cerdo condimentadas con hierbas ...
# 20  Italia  Plato de pasta tradicional de Apulia con garba...
#
#                                                 Extra
# 0                       mozzarella fresca y albahaca.
# 1        una delicia italiana para disfrutar en casa.
# 2                        mascarpone y cacao en polvo.
# 3                    un regalo tradicional en Italia.
# 4                                                 NaN
# 5                       perfecta como acompañamiento.
# 6                     suave y deliciosamente cremosa.
# 7             absorbe los sabores de forma exquisita.
# 8        la esencia de la cultura del café en Italia.
# 9                    un bocado delicioso y saludable.
# 10               ideales con salsa de tomate o crema.
# 11                            simplemente deliciosos.
# 12          ideal para platos de pasta tradicionales.
# 13   una receta tradicional que realza el sabor de...
# 14                  perfecto para aderezos y cocinar.
# 15   madurado durante meses para obtener su sabor ...
# 16   un acompañamiento perfecto para tablas de emb...
# 17                 un postre refrescante y delicioso.
# 18                           una delicia tradicional.
# 19                         perfectas para aperitivos.
# 20                             una combinación única.

# %%
# Corregir nombres de las cabeceras de los dataframe
lista_df2 = [ventas_df, cambio_productos, clientes_df]

for df in lista_df2:
    df.columns = [col.capitalize() for col in df.columns]

# %%
ventas_df.head()
# Out:
#    Id_cliente Id_producto Fecha_venta  Cantidad  Total
# 0         723          A1  2023-11-22         2  17.98
# 1         498          C3  2023-11-21         1   5.49
# 2         121          D4  2023-11-20         3  32.97
# 3         885         L12  2023-11-19         1   6.49
# 4         347         Q17  2023-11-18         2   7.98

# %%
cambio_productos.head()
# Out:
#    Id         Nombre_producto          Categoría  Precio  Origen  \
# 0  A1        Pizza Margherita  Platos Preparados    8.99  Italia
# 1  B2  Risotto de Champiñones  Platos Preparados    6.75  Italia
# 2  C3                Tiramisú            Postres    5.49  Italia
# 3  D4               Panettone         Repostería   10.99  Italia
# 4  E5             Orecchiette    Productos Secos    4.29  Italia
#
#                                          Descripción  \
# 0                  Clásica pizza italiana con tomate
# 1            Risotto cremoso con champiñones frescos
# 2  Postre clásico italiano con capas de bizcocho ...
# 3  Pan dulce navideño italiano con frutas confita...
# 4  Pequeñas pastas con forma de orecchiette ideal...
#
#                                            Extra
# 0                  mozzarella fresca y albahaca.
# 1   una delicia italiana para disfrutar en casa.
# 2                   mascarpone y cacao en polvo.
# 3               un regalo tradicional en Italia.
# 4                                            NaN

# %%
clientes_df.head()
# Out:
#    Id  First_name Last_name                         Email  Gender  \
# 0   1       Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 1   2        Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 2   3  Michaeline   Paynton            mpaynton2@narod.ru  Female
# 3   4      Filmer    Eirwin            feirwin3@intel.com     NaN
# 4   5      Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
#
#                           City Country                   Address
# 0            Palma De Mallorca   Spain  076 Rockefeller Crossing
# 1                         Lugo   Spain        0046 Utah Junction
# 2                          NaN   Spain          0 Corry Crossing
# 3                         Leon   Spain       5 American Ash Road
# 4  Hospitalet De Llobregat, L'   Spain         9289 Merry Circle

# %%
# No hay presencia de duplicados en ninguno de los dataframes general.

# %%
# Manejo de nulos:
# Ventas: No hay nulos
# Productos: presencia de 1 no convertimos a desconocido
cambio_productos["Descripción"]= cambio_productos["Descripción"].fillna("Desconocido")

# %%
# Clientes: 
# calculamos el % de nulos por columna
df_nulos = pd.DataFrame((clientes_df.isnull().sum() / clientes_df.shape[0]) * 100, columns = ["%_nulos"])
# filtramos el DataFrame para quedarnos solo con aquellas columnas que tengan nulos
df_nulos[df_nulos["%_nulos"] > 0]
# Out:
#          %_nulos
# email       2.70
# gender      7.70
# City       12.40
# Country    15.40
# Address     4.10

# %%
nulos_esta_cat = clientes_df[clientes_df.columns[clientes_df.isnull().any()]].select_dtypes(include = "O").columns
print("Las columnas categóricas que tienen nulos son : \n ")
print(nulos_esta_cat)
# Out:
# Las columnas categóricas que tienen nulos son :
#
# Index(['email', 'gender', 'City', 'Country', 'Address'], dtype='object')

# %% [markdown]
# 2.2 Realizar la integración de datos: Unir los conjuntos de datos apropiados para obtener una tabla única que contenga información de ventas junto con detalles de productos y clientes.

# %%
# Unir ventas_df con cambio_productos
merged_df = pd.merge(ventas_df, cambio_productos, left_on="Id_producto", right_on="Id", how='inner')

# Unir el resultado anterior con clientes_df
merged_df = pd.merge(merged_df, clientes_df, left_on='Id_cliente', right_on='Id', how='inner')

# Mostrar el DataFrame resultante
merged_df
# Out:
#    Id_cliente Id_producto Fecha_venta  Cantidad  Total Id_x  \
# 0         723          A1  2023-11-22         2  17.98   A1
# 1         498          C3  2023-11-21         1   5.49   C3
# 2         121          D4  2023-11-20         3  32.97   D4
# 3         885         L12  2023-11-19         1   6.49  L12
# 4         347         Q17  2023-11-18         2   7.98  Q17
# 5         619         T20  2023-11-17         1   7.89  T20
# 6         812         Y25  2023-11-16         2  13.50  Y25
# 7         170         U21  2023-11-15         1   5.75  U21
#
#                Nombre_producto             Categoría  Precio  Origen  \
# 0             Pizza Margherita     Platos Preparados    8.99  Italia
# 1                     Tiramisú               Postres    5.49  Italia
# 2                    Panettone            Repostería   10.99  Italia
# 3  Sardinas en Aceite de Oliva  Pescados en Conserva    3.99  Italia
# 4               Pasta de Trigo       Productos Secos    3.99  Italia
# 5              Queso Parmesano     Productos Lácteos    7.89  Italia
# 6                   Cacciatore             Embutidos    6.75  Italia
# 7               Salami Toscano             Embutidos    5.75  Italia
#
#                                          Descripción  \
# 0                  Clásica pizza italiana con tomate
# 1  Postre clásico italiano con capas de bizcocho ...
# 2  Pan dulce navideño italiano con frutas confita...
# 3                Sardinas frescas en aceite de oliva
# 4            Deliciosa pasta de trigo durum italiana
# 5                           El famoso queso italiano
# 6  Salchichas de cerdo condimentadas con hierbas ...
# 7  Salami de cerdo italiano curado con hierbas y ...
#
#                                                Extra  Id_y First_name  \
# 0                      mozzarella fresca y albahaca.   723    Sephira
# 1                       mascarpone y cacao en polvo.   498    Padgett
# 2                   un regalo tradicional en Italia.   121        Wye
# 3                   un bocado delicioso y saludable.   885    Windham
# 4          ideal para platos de pasta tradicionales.   347     Egbert
# 5   madurado durante meses para obtener su sabor ...   619      Nicky
# 6                         perfectas para aperitivos.   812      Quinn
# 7   un acompañamiento perfecto para tablas de emb...   170     Brigit
#
#    Last_name                              Email   Gender  \
# 0  Bleackley       sbleackleyk2@liveinternet.ru      NaN
# 1    Painter  ppainterdt@scientificamerican.com     Male
# 2   Sinncock                wsinncock3c@fc2.com     Male
# 3     Badham                wbadhamok@wired.com     Male
# 4   Leborgne            eleborgne9m@reuters.com     Male
# 5    Bernier             nbernierh6@4shared.com  Agender
# 6    Brenton       qbrentonmj@blogtalkradio.com   Female
# 7       Witt                     bwitt4p@va.gov   Female
#
#                           City Country                 Address
# 0                       Girona     NaN        4 Birchwood Road
# 1                    Barcelona   Spain          5 Artisan Lane
# 2                    Santander     NaN    4679 Fair Oaks Trail
# 3  Hospitalet De Llobregat, L'   Spain      68 Nelson Junction
# 4                      Sevilla   Spain            7 Quincy Way
# 5                   Valladolid   Spain        55 Waubesa Trail
# 6                        Gijon   Spain  5495 Lakeland Junction
# 7                 Dos Hermanas   Spain           38 Ohio Point

# %% [markdown]
# 2.3 Aplicar transformaciones relevantes según sea necesario: Convertir tipos de datos, renombrar columnas, crear nuevas características derivadas, etc.

# %%
merged_df.columns
# Out:
# Index(['Id_cliente', 'Id_producto', 'Fecha_venta', 'Cantidad', 'Total', 'Id_x',
#        'Nombre_producto', 'Categoría', 'Precio', 'Origen', 'Descripción',
#        'Extra', 'Id_y', 'First_name', 'Last_name', 'Email', 'Gender', 'City',
#        'Country', 'Address'],
#       dtype='object')

# %%
merged_df
# Out:
#    Id_cliente Id_producto Fecha_venta  Cantidad  Total  \
# 0         723          A1  2023-11-22         2  17.98
# 1         498          C3  2023-11-21         1   5.49
# 2         121          D4  2023-11-20         3  32.97
# 3         885         L12  2023-11-19         1   6.49
# 4         347         Q17  2023-11-18         2   7.98
# 5         619         T20  2023-11-17         1   7.89
# 6         812         Y25  2023-11-16         2  13.50
# 7         170         U21  2023-11-15         1   5.75
#
#                Nombre_producto             Categoría  Precio  Origen  \
# 0             Pizza Margherita     Platos Preparados    8.99  Italia
# 1                     Tiramisú               Postres    5.49  Italia
# 2                    Panettone            Repostería   10.99  Italia
# 3  Sardinas en Aceite de Oliva  Pescados en Conserva    3.99  Italia
# 4               Pasta de Trigo       Productos Secos    3.99  Italia
# 5              Queso Parmesano     Productos Lácteos    7.89  Italia
# 6                   Cacciatore             Embutidos    6.75  Italia
# 7               Salami Toscano             Embutidos    5.75  Italia
#
#                                          Descripción  \
# 0                  Clásica pizza italiana con tomate
# 1  Postre clásico italiano con capas de bizcocho ...
# 2  Pan dulce navideño italiano con frutas confita...
# 3                Sardinas frescas en aceite de oliva
# 4            Deliciosa pasta de trigo durum italiana
# 5                           El famoso queso italiano
# 6  Salchichas de cerdo condimentadas con hierbas ...
# 7  Salami de cerdo italiano curado con hierbas y ...
#
#                                                Extra First_name  Last_name  \
# 0                      mozzarella fresca y albahaca.    Sephira  Bleackley
# 1                       mascarpone y cacao en polvo.    Padgett    Painter
# 2                   un regalo tradicional en Italia.        Wye   Sinncock
# 3                   un bocado delicioso y saludable.    Windham     Badham
# 4          ideal para platos de pasta tradicionales.     Egbert   Leborgne
# 5   madurado durante meses para obtener su sabor ...      Nicky    Bernier
# 6                         perfectas para aperitivos.      Quinn    Brenton
# 7   un acompañamiento perfecto para tablas de emb...     Brigit       Witt
#
#                                Email   Gender                         City  \
# 0       sbleackleyk2@liveinternet.ru      NaN                       Girona
# 1  ppainterdt@scientificamerican.com     Male                    Barcelona
# 2                wsinncock3c@fc2.com     Male                    Santander
# 3                wbadhamok@wired.com     Male  Hospitalet De Llobregat, L'
# 4            eleborgne9m@reuters.com     Male                      Sevilla
# 5             nbernierh6@4shared.com  Agender                   Valladolid
# 6       qbrentonmj@blogtalkradio.com   Female                        Gijon
# 7                     bwitt4p@va.gov   Female                 Dos Hermanas
#
#   Country                 Address
# 0     NaN        4 Birchwood Road
# 1   Spain          5 Artisan Lane
# 2     NaN    4679 Fair Oaks Trail
# 3   Spain      68 Nelson Junction
# 4   Spain            7 Quincy Way
# 5   Spain        55 Waubesa Trail
# 6   Spain  5495 Lakeland Junction
# 7   Spain           38 Ohio Point

# %%
# Eliminar columnas de id redundantes si es necesario
merged_df.drop(['Id_x', 'Id_y'], axis=1, inplace=True)

# %%
merged_df.columns
# Out:
# Index(['Id_cliente', 'Id_producto', 'Fecha_venta', 'Cantidad', 'Total',
#        'Nombre_producto', 'Categoría', 'Precio', 'Origen', 'Descripción',
#        'Extra', 'First_name', 'Last_name', 'Email', 'Gender', 'City',
#        'Country', 'Address'],
#       dtype='object')

# %%
# Convertir tipos de datos si es necesario:
# Usando astype() para cambiar tipos de datos: merged_df['fecha'] = pd.to_datetime(merged_df['fecha']), NO ES NECESARIO
# Renombrar columnas, REALIZADO: merged_df.rename(columns={'nombre_producto': 'producto', 'nombre_cliente': 'cliente'}, inplace=True)
# Crear nuevas características derivadas: No es necesario: Creando una columna de ingresos totales: merged_df['ingresos_totales'] = merged_df['cantidad'] * merged_df['precio_unitario']

# Reemplazar NaN en la columna 'Country' por 'Spain'
merged_df['Country'].fillna('Spain', inplace=True)

# %%
merged_df["Country"].unique()
# Out:
# array(['Spain'], dtype=object)
